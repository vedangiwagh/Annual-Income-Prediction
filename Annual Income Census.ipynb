# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression # Logistic regression algorithm
from sklearn.model_selection import train_test_split 
from sklearn.metrics import accuracy_score # metric
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("train.csv")

# %%
data.head()
# Out:
#    age  workclass  final_weight   education  Learning years  \
# 0   31    Private         87891  Assoc-acdm              12
# 1   32  State-gov        175931     HS-grad               9
# 2   41    Private        131591     HS-grad               9
# 3   26    Private        160445     HS-grad               9
# 4   56    Private        179781     HS-grad               9
#
#        marital-status       occupation   relationship   sex  capital-gain  \
# 0  Married-civ-spouse            Sales        Husband  Male             0
# 1  Married-civ-spouse  Protective-serv        Husband  Male             0
# 2  Married-civ-spouse     Adm-clerical        Husband  Male             0
# 3            Divorced     Craft-repair  Not-in-family  Male             0
# 4  Married-civ-spouse  Exec-managerial        Husband  Male             0
#
#    capital-loss  Workrate native-country  label  Id
# 0             0        60  United-States      1   1
# 1             0        40  United-States      1   2
# ...

# %%
data.tail()
# Out:
#        age         workclass  final_weight     education  Learning years  \
# 32556   30           Private        117393       HS-grad               9
# 32557   57  Self-emp-not-inc         95280  Some-college              10
# 32558   56           Private        202220  Some-college              10
# 32559   56      Self-emp-inc        119891  Some-college              10
# 32560   29      Self-emp-inc        138597    Assoc-acdm              12
#
#            marital-status       occupation    relationship     sex  \
# 32556       Never-married            Sales   Not-in-family  Female
# 32557  Married-civ-spouse            Sales         Husband    Male
# 32558           Separated     Tech-support       Unmarried  Female
# 32559  Married-civ-spouse  Exec-managerial         Husband    Male
# 32560       Never-married   Prof-specialty  Other-relative  Female
#
#        capital-gain  capital-loss  Workrate native-country  label     Id
# ...

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.drop(["Id"],axis=1,inplace=True)

# %%
data.describe()
# Out:
#                 age  final_weight  Learning years  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04    32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05       10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05        2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04        1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05        9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05       10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05       12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06       16.000000  99999.000000   4356.000000
#
#            Workrate         label
# count  32561.000000  32561.000000
# mean      40.437456      0.759190
# std       12.347429      0.427581
# min        1.000000      0.000000
# 25%       40.000000      1.000000
# 50%       40.000000      1.000000
# ...

# %%
data["label"].value_counts()
# Out:
# 1    24720
# 0     7841
# Name: label, dtype: int64

# %%
data.dtypes
# Out:
# age                int64
# workclass         object
# final_weight       int64
# education         object
# Learning years     int64
# marital-status    object
# occupation        object
# relationship      object
# sex               object
# capital-gain       int64
# capital-loss       int64
# Workrate           int64
# native-country    object
# label              int64
# dtype: object

# %%
data.isnull().any()
# Out:
# age               False
# workclass          True
# final_weight      False
# education         False
# Learning years    False
# marital-status    False
# occupation         True
# relationship      False
# sex               False
# capital-gain      False
# capital-loss      False
# Workrate          False
# native-country     True
# label             False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,OneHotEncoder
labelencoder = LabelEncoder()
# data['workclass']=data['workclass'].astype('category')
data['workclass'] = labelencoder.fit_transform(data['workclass'].astype(str))
data['education'] = labelencoder.fit_transform(data['education'])
# data['marital-status'] = labelencoder.fit_transform(data['marital-status'])
# data['occupation']=data['occupation'].astype('category')
data['occupation'] = labelencoder.fit_transform(data['occupation'].astype(str))
# data['relationship'] = labelencoder.fit_transform(data['relationship'])
# data['sex'] = labelencoder.fit_transform(data['sex'])
data['native-country'] = labelencoder.fit_transform(data['native-country'].astype(str))
data.head()
# Out:
#    age  workclass  final_weight  education  Learning years  \
# 0   31          3         87891          7              12
# 1   32          6        175931         11               9
# 2   41          3        131591         11               9
# 3   26          3        160445         11               9
# 4   56          3        179781         11               9
#
#        marital-status  occupation   relationship   sex  capital-gain  \
# 0  Married-civ-spouse          11        Husband  Male             0
# 1  Married-civ-spouse          10        Husband  Male             0
# 2  Married-civ-spouse           0        Husband  Male             0
# 3            Divorced           2  Not-in-family  Male             0
# 4  Married-civ-spouse           3        Husband  Male             0
#
#    capital-loss  Workrate  native-country  label
# 0             0        60              38      1
# 1             0        40              38      1
# ...

# %%
data.dropna()
# Out:
#        age  workclass  final_weight  education  Learning years  \
# 0       31          3         87891          7              12
# 1       32          6        175931         11               9
# 2       41          3        131591         11               9
# 3       26          3        160445         11               9
# 4       56          3        179781         11               9
# 5       32          3        309513          7              12
# 6       20          3        221955          4               3
# 7       38          3        127601         15              10
# 8       52          3        225317          4               3
# 9       31          1        158092         15              10
# 10      52          3        109413         11               9
# 11      22          3        218343         11               9
# 12      31          3        226756         11               9
# 13      23          3        126346          6               5
# ...

# %%
data.isnull().any()
# Out:
# age               False
# workclass         False
# final_weight      False
# education         False
# Learning years    False
# marital-status    False
# occupation        False
# relationship      False
# sex               False
# capital-gain      False
# capital-loss      False
# Workrate          False
# native-country    False
# label             False
# dtype: bool

# %%
# for index, row in data.iterrows():
# #     data.at[index,'net']=data.loc[index,'capital-gain']+data.loc[index,'capital-loss']
#     if(row['age']==90):
#         data.drop(index,inplace=True)
    
#     if(row['final_weight']>=1200000):
#         data.drop(index,inplace=True)
#     if(row['capital-gain']>=40000):
#         data.drop(index,inplace=True) 
#     if(row['capital-loss']>=30000):
#         data.drop(index,inplace=True)

# %%
# cleanup_nums = {"native-country":{"United-States": 1}}

# %%
# data.replace(cleanup_nums, inplace=True)
# data.head()

# %%
cleanup_nums = {"sex":{"Female": 0,"Male": 1}}

# %%
data.replace(cleanup_nums, inplace=True)
# data.head()

# %%
# cleanup_nums = {"native-country":{"Mexico": 0,"South": 2,"Dominican-Republic":39,"Philippines":3,"Taiwan":4,"Poland":5,"Cambodia":6,"Italy":7
#                                  ,"Cuba":8,"Jamaica":9,"Vietnam":10,"Canada":11,"El-Salvador":11,"Iran":12,"China":13,"Hong":14,"Haiti":15
#                                  ,"India":16,"Trinadad&Tobago":17,"Japan":18,"England":19,"Columbia":20,"Thailand":21,"Ireland":22
#                                  ,"Germany":23,"France":24,"Guatemala":25,"Honduras":26,"Greece":27,"Nicaragua":28,
#                                  "Puerto-Rico":29,"Peru":30,"Portugal":31,"Yugoslavia":32,"Hungary":33,"Laos":34,"Ecuador":35
#                                  ,"Scotland":36,"Outlying-US(Guam-USVI-etc)":37,"Holand-Netherlands":38}}

# %%
# data.replace(cleanup_nums, inplace=True)

# %%
cleanup_nums = {"relationship":{"Husband": 1,"Other-relative": 0,"Wife":1,"Not-in-family":0,"Own-child":0,"Unmarried":0}}

# %%
data.replace(cleanup_nums, inplace=True)

# %%
# data.head()

# %%
cleanup_nums = {"marital-status":{"Married-civ-spouse": 1,"Divorced": 0,"Never-married":0,"Separated":0,
                                  "Widowed":0,"Married-spouse-absent":0,"Married-AF-spouse":1}}

# %%
data.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"workclass":{"Private": 1,"State-gov": 0,"Local-gov":2,"Federal-gov":3,"Self-emp-not-inc":4,
#                              "Self-emp-inc":5,"Without-pay":6,"Never-worked":7}}

# %%
# data.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"occupation":{"Tech-support":0,
# "Transport-moving":1,
# "Sales":2,
# "Adm-clerical":3,
# "Craft-repair":4,
# "Exec-managerial":5,
# "Handlers-cleaners":6,
# "Farming-fishing":7,
# "Sales":8,
# "Machine-op-inspct":9,
# "Prof-specialty":10,
# "Other-service":11,"Protective-serv":12,"Armed-Forces":13,"Priv-house-serv":14
# }}

# %%
# data.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"education":{"Assoc-acdm":0,
# "HS-grad":1,
# "5th-6th":2,
# "9th":3,
# "Bachelors":4,
# "Masters":5,
# "Assoc-voc":6,
# "11th":7,
# "Prof-school":8,
# "Preschool":9,
# "Prof-specialty":10,
# "10th":11,"7th-8th":12,"12th":13,"Some-college":14,"Doctorate":15,"1st-4th":16
# }}

# %%
data.to_csv("pre.csv")

# %%
data.drop(['marital-status'], axis=1, inplace=True)
# data.drop(['capital-gain'], axis=1, inplace=True)
# data.drop(['sex'], axis=1, inplace=True)
data.drop(['education'], axis=1, inplace=True)
# data.drop(['capital-loss'], axis=1, inplace=True)
# data.drop(['native-country'], axis=1, inplace=True)

# %%
# data.replace(cleanup_nums, inplace=True)
data.corr()
# Out:
#                      age  workclass  final_weight  Learning years  occupation  \
# age             1.000000   0.059423     -0.076646        0.036527    0.012626
# workclass       0.059423   1.000000     -0.019164       -0.054350    0.312511
# final_weight   -0.076646  -0.019164      1.000000       -0.043195   -0.000521
# Learning years  0.036527  -0.054350     -0.043195        1.000000    0.044096
# occupation      0.012626   0.312511     -0.000521        0.044096    1.000000
# relationship    0.321457   0.001692     -0.028114        0.092133   -0.000095
# sex             0.088832   0.002306      0.026858        0.012280    0.026116
# capital-gain    0.077674   0.010687      0.000432        0.122630    0.012350
# capital-loss    0.057775  -0.009888     -0.010252        0.079923    0.004540
# Workrate        0.068756  -0.093411     -0.018768        0.148123   -0.056995
# native-country -0.000176   0.001253     -0.062710        0.090277   -0.000479
# ...

# %%
data.describe()
# Out:
#                 age     workclass  final_weight  Learning years    occupation  \
# count  32561.000000  32561.000000  3.256100e+04    32561.000000  32561.000000
# mean      38.581647      3.376371  1.897784e+05       10.080679      6.421762
# std       13.640433      1.582038  1.055500e+05        2.572720      4.328619
# min       17.000000      0.000000  1.228500e+04        1.000000      0.000000
# 25%       28.000000      3.000000  1.178270e+05        9.000000      3.000000
# 50%       37.000000      3.000000  1.783560e+05       10.000000      6.000000
# 75%       48.000000      3.000000  2.370510e+05       12.000000     10.000000
# max       90.000000      8.000000  1.484705e+06       16.000000     14.000000
#
#        relationship           sex  capital-gain  capital-loss      Workrate  \
# count  32561.000000  32561.000000  32561.000000  32561.000000  32561.000000
# mean       0.453334      0.669205   1077.648844     87.303830     40.437456
# ...

# %%
# data["occupation"].fillna("6.499935", inplace = True) 
# data["native-country"].fillna("2.005410", inplace = True) 
# data["workclass"].fillna("1.485403", inplace = True)

# %%
data.isnull().any()
# Out:
# age               False
# workclass         False
# final_weight      False
# Learning years    False
# occupation        False
# relationship      False
# sex               False
# capital-gain      False
# capital-loss      False
# Workrate          False
# native-country    False
# label             False
# dtype: bool

# %%
data["label"] = data["label"].map({1:0,0:1})
# data = data.drop(["age"],axis=1)

data.head()
# Out:
#    age  workclass  final_weight  Learning years  occupation  relationship  \
# 0   31          3         87891              12          11             1
# 1   32          6        175931               9          10             1
# 2   41          3        131591               9           0             1
# 3   26          3        160445               9           2             0
# 4   56          3        179781               9           3             1
#
#    sex  capital-gain  capital-loss  Workrate  native-country  label
# 0    1             0             0        60              38      0
# 1    1             0             0        40              38      0
# 2    1             0             0        45              38      0
# 3    1             0             0        40              38      0
# 4    1             0             0        40              38      1

# %%
y = data["label"]

X = data.drop(["label"],axis=1)

X.shape
# Out:
# (32561, 11)

# %%
x_train , x_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
lr = LogisticRegression(C=1.3,max_iter=100)

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.3, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
prediction_train = lr.predict(X_train)
print(accuracy_score(y_true=y_train,y_pred=prediction_train))
# Out:
# 0.8429437960687961

# %%
prediction_test = lr.predict(X_test)
print(accuracy_score(y_true=y_test,y_pred=prediction_test))
# Out:
# 0.8446184553968985

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
from sklearn.svm import SVC
clf = SVC(gamma='auto',C=3.5,cache_size=1000,kernel='rbf')
clf.fit(X_train, y_train)
# Out:
# SVC(C=3.5, cache_size=1000, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
prediction_train1 = clf.predict(X_train)
print(accuracy_score(y_true=y_train,y_pred=prediction_train1))
prediction_test1 = clf.predict(X_test)
y_true=y_test
y_pred=prediction_test1
print(accuracy_score(y_true=y_test,y_pred=prediction_test1))
# Out:
# 0.859720515970516
# 0.852141870105942

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true, y_pred)
# Out:
# array([[4676,  265],
#        [ 698,  874]])

# %%
# from sklearn.neighbors import KNeighborsClassifier

# knn = KNeighborsClassifier(n_neighbors=31)
# # fit the model with data
# knn.fit(X_train, y_train)
# k_pred = knn.predict(X_train)
# print(accuracy_score(y_true=y_train,y_pred=k_pred))
# prediction_test1 = knn.predict(X_test)
# print(accuracy_score(y_true=y_test,y_pred=prediction_test1))

# %%
scaler=StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
# from sklearn.ensemble import RandomForestClassifier
# rf = RandomForestClassifier()
# rf.fit(X_train, y_train)

# %%
# prediction_train1 = rf.predict(X_train)
# print(accuracy_score(y_true=y_train,y_pred=prediction_train1))
# prediction_test1 = rf.predict(X_test)
# y_true=y_test
# y_pred=prediction_test1
# print(accuracy_score(y_true=y_test,y_pred=prediction_test1))

# %%
from sklearn.ensemble import GradientBoostingClassifier
gf = GradientBoostingClassifier()
gf.fit(X_train, y_train) 
prediction_train1 = gf.predict(X_train)
print(accuracy_score(y_true=y_train,y_pred=prediction_train1))
prediction_test1 = gf.predict(X_test)
y_true=y_test
y_pred=prediction_test1
print(accuracy_score(y_true=y_test,y_pred=prediction_test1))
# Out:
# /home/redhat/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# 0.8685119778869779
# 0.8667280822969445

# %%
from catboost import CatBoostClassifier
# from xgboost import XGBClassifier

# cxg= XGBClassifier()
ct= CatBoostClassifier()
ct.fit(X_train, y_train) 
prediction_train1 = ct.predict(X_train)
print(accuracy_score(y_true=y_train,y_pred=prediction_train1))
prediction_test1 = ct.predict(X_test)
y_true=y_test
y_pred=prediction_test1
print(accuracy_score(y_true=y_test,y_pred=prediction_test1))
# Out:
# Learning rate set to 0.042149
# 0:	learn: 0.6504202	total: 95.7ms	remaining: 1m 35s
# 1:	learn: 0.6128022	total: 118ms	remaining: 59.1s
# 2:	learn: 0.5821701	total: 169ms	remaining: 56.3s
# 3:	learn: 0.5537279	total: 202ms	remaining: 50.2s
# 4:	learn: 0.5261640	total: 262ms	remaining: 52.1s
# 5:	learn: 0.5058241	total: 288ms	remaining: 47.7s
# 6:	learn: 0.4839989	total: 353ms	remaining: 50s
# 7:	learn: 0.4659145	total: 406ms	remaining: 50.3s
# 8:	learn: 0.4513523	total: 446ms	remaining: 49.1s
# 9:	learn: 0.4380277	total: 499ms	remaining: 49.4s
# 10:	learn: 0.4253922	total: 527ms	remaining: 47.4s
# 11:	learn: 0.4160626	total: 584ms	remaining: 48.1s
# 12:	learn: 0.4068309	total: 613ms	remaining: 46.5s
# 13:	learn: 0.3975121	total: 679ms	remaining: 47.8s
# 14:	learn: 0.3896908	total: 704ms	remaining: 46.3s
# 15:	learn: 0.3829002	total: 761ms	remaining: 46.8s
# 16:	learn: 0.3771617	total: 787ms	remaining: 45.5s
# 17:	learn: 0.3709656	total: 860ms	remaining: 46.9s
# ...

# %%
data1 = pd.read_csv("test.csv")

# %%
data1.isnull().any()
# Out:
# age               False
# workclass          True
# final_weight      False
# education         False
# Learning years    False
# marital-status    False
# occupation         True
# relationship      False
# sex               False
# capital-gain      False
# capital-loss      False
# Workrate          False
# native-country     True
# Id                False
# dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder,MinMaxScaler,OneHotEncoder
labelencoder = LabelEncoder()
# data['workclass']=data['workclass'].astype('category')
data1['workclass'] = labelencoder.fit_transform(data1['workclass'].astype(str))
data1['education'] = labelencoder.fit_transform(data1['education'])
# data1['marital-status'] = labelencoder.fit_transform(data1['marital-status'])
# data['occupation']=data['occupation'].astype('category')
data1['occupation'] = labelencoder.fit_transform(data1['occupation'].astype(str))
# data1['relationship'] = labelencoder.fit_transform(data1['relationship'])
# data1['sex'] = labelencoder.fit_transform(data1['sex'])
data1['native-country'] = labelencoder.fit_transform(data1['native-country'].astype(str))
data1.head()
# Out:
#    age  workclass  final_weight  education  Learning years  \
# 0   49          3        182313         11               9
# 1   66          5        183249          9              13
# 2   26          3        264300          7              12
# 3   43          1        201764         14              15
# 4   63          0         90393         15              10
#
#        marital-status  occupation   relationship     sex  capital-gain  \
# 0            Divorced           5  Not-in-family    Male             0
# 1  Married-civ-spouse           9        Husband    Male             0
# 2       Never-married           0      Own-child  Female             0
# 3       Never-married           9  Not-in-family    Male             0
# 4  Married-civ-spouse           0        Husband    Male             0
#
#    capital-loss  Workrate  native-country     Id
# 0             0        40              37  32562
# 1             0        20              37  32563
# ...

# %%
data1.describe()
# Out:
#                 age     workclass  final_weight     education  Learning years  \
# count  16281.000000  16281.000000  1.628100e+04  16281.000000    16281.000000
# mean      38.767459      3.405872  1.894357e+05     10.268841       10.072907
# std       13.849187      1.605006  1.057149e+05      3.882980        2.567545
# min       17.000000      0.000000  1.349200e+04      0.000000        1.000000
# 25%       28.000000      3.000000  1.167360e+05      9.000000        9.000000
# 50%       37.000000      3.000000  1.778310e+05     11.000000       10.000000
# 75%       48.000000      3.000000  2.383840e+05     12.000000       12.000000
# max       90.000000      8.000000  1.490400e+06     15.000000       16.000000
#
#          occupation  capital-gain  capital-loss      Workrate  native-country  \
# count  16281.000000  16281.000000  16281.000000  16281.000000    16281.000000
# mean       6.477612   1081.905104     87.899269     40.392236       35.546342
# ...

# %%
data1["occupation"].fillna("6.337141", inplace = True) 
data1["native-country"].fillna("30.036361", inplace = True) 
data1["workclass"].fillna("3.873534", inplace = True)

# %%
# for index, row in data1.iterrows():
#     data1.at[index,'net']=data1.loc[index,'capital-gain']+data1.loc[index,'capital-loss']

# %%
data1.drop(['marital-status'], axis=1, inplace=True)
# data1.drop(['capital-gain'], axis=1, inplace=True)
data1.drop(['education'], axis=1, inplace=True)
# data1.drop(['capital-loss'], axis=1, inplace=True)
# data1.drop(['sex'], axis=1, inplace=True)
# data1.drop(['native-country'], axis=1, inplace=True)

# %%
# cleanup_nums = {"native-country":{"United-States": 1}}

# %%
# data1.replace(cleanup_nums, inplace=True)

# %%
cleanup_nums = {"sex":{"Female": 0,"Male": 1}}

# %%
data1.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"native-country":{"Mexico": 0,"South": 2,"Dominican-Republic":39,"Philippines":3,"Taiwan":4,"Poland":5,"Cambodia":6,"Italy":7
#                                  ,"Cuba":8,"Jamaica":9,"Vietnam":10,"Canada":11,"El-Salvador":11,"Iran":12,"China":13,"Hong":14,"Haiti":15
#                                  ,"India":16,"Trinadad&Tobago":17,"Japan":18,"England":19,"Columbia":20,"Thailand":21,"Ireland":22
#                                  ,"Germany":23,"France":24,"Guatemala":25,"Honduras":26,"Greece":27,"Nicaragua":28,
#                                  "Puerto-Rico":29,"Peru":30,"Portugal":31,"Yugoslavia":32,"Hungary":33,"Laos":34,"Ecuador":35
#                                  ,"Scotland":36,"Outlying-US(Guam-USVI-etc)":37,"Holand-Netherlands":38}}

# %%
# data1.replace(cleanup_nums, inplace=True)

# %%
cleanup_nums = {"relationship":{"Husband": 1,"Other-relative": 0,"Wife":1,"Not-in-family":0,"Own-child":0,"Unmarried":0}}

# %%
data1.replace(cleanup_nums, inplace=True)

# %%
cleanup_nums = {"marital-status":{"Married-civ-spouse": 1,"Divorced": 0,"Never-married":0,"Separated":0,
                                  "Widowed":0,"Married-spouse-absent":0,"Married-AF-spouse":1}}

# %%
data1.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"workclass":{"Private": 1,"State-gov": 0,"Local-gov":2,"Federal-gov":3,"Self-emp-not-inc":4,
#                              "Self-emp-inc":5,"Without-pay":6,"Never-worked":7}}

# %%
# data1.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"occupation":{"Tech-support":0,
# "Transport-moving":1,
# "Sales":2,
# "Adm-clerical":3,
# "Craft-repair":4,
# "Exec-managerial":5,
# "Handlers-cleaners":6,
# "Farming-fishing":7,
# "Sales":8,
# "Machine-op-inspct":9,
# "Prof-specialty":10,
# "Other-service":11,"Protective-serv":12,"Armed-Forces":13,"Priv-house-serv":14
# }}

# %%
# data1.replace(cleanup_nums, inplace=True)

# %%
# cleanup_nums = {"education":{"Assoc-acdm":0,
# "HS-grad":1,
# "5th-6th":2,
# "9th":3,
# "Bachelors":4,
# "Masters":5,
# "Assoc-voc":6,
# "11th":7,
# "Prof-school":8,
# "Preschool":9,
# "Prof-specialty":10,
# "10th":11,"7th-8th":12,"12th":13,"Some-college":14,"Doctorate":15,"1st-4th":16
# }}

# %%
data1.head()
# Out:
#    age  workclass  final_weight  Learning years  occupation  relationship  \
# 0   49          3        182313               9           5             0
# 1   66          5        183249              13           9             1
# 2   26          3        264300              12           0             0
# 3   43          1        201764              15           9             0
# 4   63          0         90393              10           0             1
#
#    sex  capital-gain  capital-loss  Workrate  native-country     Id
# 0    1             0             0        40              37  32562
# 1    1             0             0        20              37  32563
# 2    0             0             0        40              37  32564
# 3    1             0             0        40              37  32565
# 4    1             0             0        48              37  32566

# %%
data1.shape
# Out:
# (16281, 12)

# %%
Id = data1["Id"]

# %%
# data1= data1.drop(["relationship"],axis=1)
X1=data1.drop(["Id"],axis=1)

# %%
scaler=StandardScaler()
X1 = scaler.fit_transform(X1)
X1.shape
# Out:
# (16281, 11)

# %%
X.shape
# Out:
# (32561, 11)

# %%
prediction_test=ct.predict(X1)

# %%
prediction_test=prediction_test.astype(int)

# %%
my_solution=pd.DataFrame(prediction_test,Id,columns=["Prediction"])
print(my_solution.shape)
# Out:
# (16281, 1)

# %%
my_solution.to_csv("prediction123.csv",index_label=["Id"])
